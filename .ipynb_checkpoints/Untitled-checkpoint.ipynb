# %%
import matplotlib.pyplot as plt

# %%
file_sin = open('C://Users//79247//Desktop//1//C-tasks//x.txt', 'r')
file_sinf = open('C://Users//79247//Desktop//1//C-tasks//y.txt', 'r')
sin = []
sinf = []

for line_sin in file_sin:
   sin.append(float(line_sin))
    
for line_sinf in file_sinf:
   sinf.append(float(line_sinf))

plt.plot(sin, sinf)
